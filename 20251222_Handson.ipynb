# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarbhadra7/Testing/blob/master/20251222_Handson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
q,r=divmod(20,8)

# %%
q
# Out:
# 2

# %%
r
# Out:
# 4

# %%
a,b,*t=range(5)

# %%
print(t)
# Out:
# [2, 3, 4]

# %%
a
# Out:
# 0

# %%
b
# Out:
# 1

# %%
*range(4),4
# Out:
# (0, 1, 2, 3, 4)

# %%
{*range(4),4,*(5,6,7)}
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %%
board = [['_'] * 3 for i in range(3)]  * 3

# %%
board
# Out:
# [['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_'],
#  ['_', '_', '_']]

# %%
t=(1,2,[30,40])

# %%
t[2]+=[50,60]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-358899304.py in <cell line: 0>()
# ----> 1 t[2]+=[50,60]
#
# TypeError: 'tuple' object does not support item assignment

# %%
l= 5 *'abcd'
l
# Out:
# 'abcdabcdabcdabcdabcd'

# %%
colors=['black','white']
sizes=['s','m','l','xl','xxl']
mart=[(color,size) for color in colors for size in sizes]
mart
# Out:
# [('black', 's'),
#  ('black', 'm'),
#  ('black', 'l'),
#  ('black', 'xl'),
#  ('black', 'xxl'),
#  ('white', 's'),
#  ('white', 'm'),
#  ('white', 'l'),
#  ('white', 'xl'),
#  ('white', 'xxl')]
